# %% [markdown]
# <a href="https://colab.research.google.com/github/UmbraVenus/DreamscapeColab/blob/main/coverart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pylast
# !pip install pillow

# %%
import pylast
import requests
from PIL import Image
import urllib.request

# %%
API_KEY = "959f9e4bef8c344d9931c174b570766f"
API_SECRET = "07ca82ca31889f736dd709c4501506b8"

# %%
network = pylast.LastFMNetwork(
    api_key = API_KEY,
    api_secret = API_SECRET,
)

# %%
network.get_top_tracks()[0]
# Out:
# TopItem(item=pylast.Track('Olivia Rodrigo', 'good 4 u', pylast.LastFMNetwork('959f9e4bef8c344d9931c174b570766f', '07ca82ca31889f736dd709c4501506b8', '', '', '')), weight=8867569)

# %%
top = network.get_album("Olivia Rodrigo",'good 4 u')

# %%
sample = requests.get(top.get_cover_image(),stream=True).raw
Image.open(sample)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=300x300 at 0x7F3D2E9C8290>
